# %%
li = []
x = []
with open('Lab8.txt', 'r') as f:
    for str in f:
        li.append(str)

# %%
for i in li:
    i.replace('\n', '')
    x.append(i.split('\t'))
x
# Out:
# [['Time', 'Amplitude\n'],
#  ['0', '0.345321\n'],
#  ['0.05', '0.371093\n'],
#  ['0.1', '0.41104\n'],
#  ['0.15', '0.444544\n'],
#  ['0.2', '0.414906\n'],
#  ['0.25', '0.427792\n'],
#  ['0.3', '0.416195\n'],
#  ['0.35', '0.439389\n'],
#  ['0.4', '0.449698\n'],
#  ['0.45', '0.438101\n'],
#  ['0.5', '0.476759\n'],
#  ['0.55', '0.427792\n'],
#  ['0.6', '0.438101\n'],
#  ['0.65', '0.350476\n'],
#  ['0.7', '0.338878\n'],
#  ['0.75', '0.336301\n'],
#  ['0.8', '0.37367\n'],
#  ['0.85', '0.398154\n'],
#  ['0.9', '0.404597\n'],
#  ['0.95', '0.389134\n'],
#  ['1', '0.41104\n'],
#  ['1.05', '0.434235\n'],
#  ['1.1', '0.404597\n'],
#  ['1.15', '0.36465\n'],
#  ['1.2', '0.408463\n'],
#  ['1.25', '0.430369\n'],
#  ['1.3', '0.441967\n'],
#  ['1.35', '0.353053\n'],
#  ['1.4', '0.322126\n'],
#  ['1.45', '0.35563\n'],
#  ['1.5', '0.365939\n'],
#  ['1.55', '0.387845\n'],
#  ['1.6', '0.386557\n'],
#  ['1.65', '0.369805\n'],
#  ['1.7', '0.40202\n'],
#  ['1.75', '0.417483\n'],
#  ['1.8', '0.435524\n'],
# ...
