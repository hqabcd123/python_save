# %%
#Main
import requests
from bs4 import BeautifulSoup
import json
import time
import sqlite3 as lite

base = 'https://lihkg.com/'
uri = 'api_v2/thread/latest?cat_id={}&page=1&count=60&type=now'
url = {}
user = []

res = requests.get(base + uri.format(1))
data = json.loads(res.text)
data
#soup = BeautifulSoup(data, 'lxml')
# Out:
# {'success': 1,
#  'server_time': 1556137449,
#  'response': {'category': {'cat_id': '1', 'name': '吹水台', 'postable': True},
#   'is_pagination': True,
#   'items': [{'thread_id': '1123543',
#     'cat_id': '6',
#     'sub_cat_id': '0',
#     'title': '[靜觀其變] 利物浦對哈德斯菲爾德 3',
#     'user_id': '26708',
#     'user_nickname': '小新小葵',
#     'user_gender': 'M',
#     'no_of_reply': '883',
#     'no_of_uni_user_reply': '167',
#     'like_count': '17',
#     'dislike_count': '4',
#     'reply_like_count': '197',
#     'reply_dislike_count': '161',
#     'max_reply_like_count': '8',
#     'max_reply_dislike_count': '1',
#     'create_time': 1556113796,
#     'last_reply_time': 1556137448,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '129924',
#     'max_reply': '1001',
#     'total_page': 36,
#     'is_hot': True,
#     'category': {'cat_id': '6', 'name': '體育台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '26708',
#      'nickname': '小新小葵',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1480176399,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1116179',
#     'cat_id': '30',
#     'sub_cat_id': '0',
#     'title': '【廿一世紀男士必讀 !】黃心穎式姣閪港女圖鑑',
#     'user_id': '244243',
#     'user_nickname': '東華護士雞黃恩彤',
#     'user_gender': 'F',
#     'no_of_reply': '183',
#     'no_of_uni_user_reply': '82',
#     'like_count': '538',
#     'dislike_count': '36',
#     'reply_like_count': '491',
#     'reply_dislike_count': '136',
#     'max_reply_like_count': '96',
#     'max_reply_dislike_count': '5',
#     'create_time': 1555695705,
#     'last_reply_time': 1556137426,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 5},
#     'last_reply_user_id': '180913',
#     'max_reply': '1001',
#     'total_page': 8,
#     'is_hot': True,
#     'category': {'cat_id': '30', 'name': '感情台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '244243',
#      'nickname': '東華護士雞黃恩彤',
#      'level': '10',
#      'gender': 'F',
#      'status': '1',
#      'create_time': 1553348275,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123650',
#     'cat_id': '7',
#     'sub_cat_id': '0',
#     'title': '通常d臭雞應該有樣睇，大家講講有咩特徵？',
#     'user_id': '168882',
#     'user_nickname': '大鵰',
#     'user_gender': 'M',
#     'no_of_reply': '121',
#     'no_of_uni_user_reply': '56',
#     'like_count': '50',
#     'dislike_count': '82',
#     'reply_like_count': '1427',
#     'reply_dislike_count': '400',
#     'max_reply_like_count': '156',
#     'max_reply_dislike_count': '2',
#     'create_time': 1556117199,
#     'last_reply_time': 1556137424,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '245893',
#     'max_reply': '1001',
#     'total_page': 5,
#     'is_hot': True,
#     'category': {'cat_id': '7', 'name': '娛樂台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '168882',
#      'nickname': '大鵰',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1516958900,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123958',
#     'cat_id': '11',
#     'sub_cat_id': '0',
#     'title': '慎入 [全劇透] 復仇者聯盟 4 終局之戰 Avengers: Endgame 全劇透 10',
#     'user_id': '20294',
#     'user_nickname': '彭于晏(Eddie)',
#     'user_gender': 'M',
#     'no_of_reply': '642',
#     'no_of_uni_user_reply': '139',
#     'like_count': '49',
#     'dislike_count': '2',
#     'reply_like_count': '1050',
#     'reply_dislike_count': '299',
#     'max_reply_like_count': '48',
#     'max_reply_dislike_count': '1',
#     'create_time': 1556131223,
#     'last_reply_time': 1556137446,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '15415',
#     'max_reply': '1001',
#     'total_page': 26,
#     'is_hot': True,
#     'category': {'cat_id': '11', 'name': '影視台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '20294',
#      'nickname': '彭于晏(Eddie)',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1480130994,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1122878',
#     'cat_id': '11',
#     'sub_cat_id': '0',
#     'title': '[非劇透] 復仇者聯盟 入場前要知道的10件事',
#     'user_id': '7814',
#     'user_nickname': '大頭蝦芒果沙律',
#     'user_gender': 'F',
#     'no_of_reply': '512',
#     'no_of_uni_user_reply': '447',
#     'like_count': '5449',
#     'dislike_count': '39',
#     'reply_like_count': '4398',
#     'reply_dislike_count': '155',
#     'max_reply_like_count': '1264',
#     'max_reply_dislike_count': '6',
#     'create_time': 1556090905,
#     'last_reply_time': 1556137421,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '25218',
#     'max_reply': '1001',
#     'total_page': 21,
#     'is_hot': False,
#     'category': {'cat_id': '11', 'name': '影視台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '7814',
#      'nickname': '大頭蝦芒果沙律',
#      'level': '10',
#      'gender': 'F',
#      'status': '1',
#      'create_time': 1480088148,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1098889',
#     'cat_id': '12',
#     'sub_cat_id': '0',
#     'title': '【互動故】模擬人生',
#     'user_id': '161406',
#     'user_nickname': '倖存',
#     'user_gender': 'M',
#     'no_of_reply': '813',
#     'no_of_uni_user_reply': '95',
#     'like_count': '52',
#     'dislike_count': '10',
#     'reply_like_count': '979',
#     'reply_dislike_count': '79',
#     'max_reply_like_count': '20',
#     'max_reply_dislike_count': '1',
#     'create_time': 1554810160,
#     'last_reply_time': 1556137420,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '204196',
#     'max_reply': '1001',
#     'total_page': 33,
#     'is_hot': False,
#     'category': {'cat_id': '12', 'name': '講故台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '161406',
#      'nickname': '倖存',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1512286939,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1122130',
#     'cat_id': '31',
#     'sub_cat_id': '0',
#     'title': '［練字］你講我寫到凌晨五點',
#     'user_id': '44641',
#     'user_nickname': '恐懼先生',
#     'user_gender': 'M',
#     'no_of_reply': '123',
#     'no_of_uni_user_reply': '55',
#     'like_count': '5',
#     'dislike_count': '4',
#     'reply_like_count': '44',
#     'reply_dislike_count': '19',
#     'max_reply_like_count': '7',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556045829,
#     'last_reply_time': 1556137415,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '241543',
#     'max_reply': '1001',
#     'total_page': 5,
#     'is_hot': False,
#     'category': {'cat_id': '31', 'name': '創意台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '44641',
#      'nickname': '恐懼先生',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1480474862,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123795',
#     'cat_id': '8',
#     'sub_cat_id': '0',
#     'title': '一拳超人2期動畫製作人細谷伸之原因大概話one畫風得罪村田雄介',
#     'user_id': '3020',
#     'user_nickname': '遠阪凜',
#     'user_gender': 'F',
#     'no_of_reply': '81',
#     'no_of_uni_user_reply': '60',
#     'like_count': '14',
#     'dislike_count': '75',
#     'reply_like_count': '772',
#     'reply_dislike_count': '108',
#     'max_reply_like_count': '135',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556122594,
#     'last_reply_time': 1556137399,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '224429',
#     'max_reply': '1001',
#     'total_page': 4,
#     'is_hot': True,
#     'category': {'cat_id': '8', 'name': '動漫台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '3020',
#      'nickname': '遠阪凜',
#      'level': '10',
#      'gender': 'F',
#      'status': '1',
#      'create_time': 1480084183,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1124005',
#     'cat_id': '30',
#     'sub_cat_id': '0',
#     'title': '點忘記一個唔鐘意你既人',
#     'user_id': '193492',
#     'user_nickname': '其實我鐘意妳啊',
#     'user_gender': 'M',
#     'no_of_reply': '33',
#     'no_of_uni_user_reply': '10',
#     'like_count': '0',
#     'dislike_count': '0',
#     'reply_like_count': '12',
#     'reply_dislike_count': '1',
#     'max_reply_like_count': '4',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556135746,
#     'last_reply_time': 1556137387,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '193492',
#     'max_reply': '1001',
#     'total_page': 2,
#     'is_hot': False,
#     'category': {'cat_id': '30', 'name': '感情台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '193492',
#      'nickname': '其實我鐘意妳啊',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1530757980,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123774',
#     'cat_id': '19',
#     'sub_cat_id': '0',
#     'title': '想轉讀護理學應該點走落去',
#     'user_id': '187714',
#     'user_nickname': '荃灣Chester',
#     'user_gender': 'M',
#     'no_of_reply': '29',
#     'no_of_uni_user_reply': '12',
#     'like_count': '3',
#     'dislike_count': '15',
#     'reply_like_count': '23',
#     'reply_dislike_count': '23',
#     'max_reply_like_count': '6',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556121709,
#     'last_reply_time': 1556137445,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 3},
#     'last_reply_user_id': '187714',
#     'max_reply': '1001',
#     'total_page': 2,
#     'is_hot': False,
#     'category': {'cat_id': '19', 'name': '校園台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '187714',
#      'nickname': '荃灣Chester',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1526887914,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1106967',
#     'cat_id': '10',
#     'sub_cat_id': '0',
#     'title': '【日本Falcom】綜合討論區Vol.42【- 亞莉莎係女主角 -】',
#     'user_id': '31585',
#     'user_nickname': '相樂真由加藤恵',
#     'user_gender': 'M',
#     'no_of_reply': '755',
#     'no_of_uni_user_reply': '24',
#     'like_count': '1',
#     'dislike_count': '3',
#     'reply_like_count': '38',
#     'reply_dislike_count': '23',
#     'max_reply_like_count': '5',
#     'max_reply_dislike_count': '0',
#     'create_time': 1555294126,
#     'last_reply_time': 1556137336,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 2},
#     'last_reply_user_id': '52423',
#     'max_reply': '1001',
#     'total_page': 31,
#     'is_hot': False,
#     'category': {'cat_id': '10', 'name': '遊戲台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '31585',
#      'nickname': '相樂真由加藤恵',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1480270856,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '969967',
#     'cat_id': '12',
#     'sub_cat_id': '0',
#     'title': '（荃灣）那年日食，我開始記錄低關於蜥蜴人影子政府嘅一切真相（2）',
#     'user_id': '217418',
#     'user_nickname': '林泳',
#     'user_gender': 'M',
#     'no_of_reply': '930',
#     'no_of_uni_user_reply': '56',
#     'like_count': '45',
#     'dislike_count': '11',
#     'reply_like_count': '501',
#     'reply_dislike_count': '25',
#     'max_reply_like_count': '12',
#     'max_reply_dislike_count': '0',
#     'create_time': 1546691734,
#     'last_reply_time': 1556137332,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '153570',
#     'max_reply': '1001',
#     'total_page': 38,
#     'is_hot': False,
#     'category': {'cat_id': '12', 'name': '講故台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '217418',
#      'nickname': '林泳',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1539923516,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123581',
#     'cat_id': '1',
#     'sub_cat_id': '0',
#     'title': '去睇戲唔該叫個細路唔好嘈',
#     'user_id': '204457',
#     'user_nickname': '藍眼睛的愛麗絲',
#     'user_gender': 'F',
#     'no_of_reply': '30',
#     'no_of_uni_user_reply': '13',
#     'like_count': '45',
#     'dislike_count': '1',
#     'reply_like_count': '53',
#     'reply_dislike_count': '23',
#     'max_reply_like_count': '33',
#     'max_reply_dislike_count': '1',
#     'create_time': 1556114900,
#     'last_reply_time': 1556137313,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 3},
#     'last_reply_user_id': '204457',
#     'max_reply': '1001',
#     'total_page': 2,
#     'is_hot': False,
#     'category': {'cat_id': '1', 'name': '吹水台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '204457',
#      'nickname': '藍眼睛的愛麗絲',
#      'level': '10',
#      'gender': 'F',
#      'status': '1',
#      'create_time': 1535393526,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123456',
#     'cat_id': '18',
#     'sub_cat_id': '6',
#     'title': '點解偷野會叫做m野？',
#     'user_id': '141400',
#     'user_nickname': 'Winthepool',
#     'user_gender': 'M',
#     'no_of_reply': '168',
#     'no_of_uni_user_reply': '121',
#     'like_count': '652',
#     'dislike_count': '21',
#     'reply_like_count': '5628',
#     'reply_dislike_count': '1202',
#     'max_reply_like_count': '772',
#     'max_reply_dislike_count': '5',
#     'create_time': 1556110452,
#     'last_reply_time': 1556137293,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 2},
#     'last_reply_user_id': '229955',
#     'max_reply': '1001',
#     'total_page': 7,
#     'is_hot': True,
#     'category': {'cat_id': '18', 'name': '學術台', 'postable': True},
#     'sub_category': {'sub_cat_id': '6',
#      'cat_id': '18',
#      'name': '神秘',
#      'postable': True,
#      'filterable': True,
#      'is_highlight': False,
#      'orderable': True,
#      'is_filter': False,
#      'url': 'https://lihkg.com/api_v2/thread/category',
#      'query': {'cat_id': '18', 'sub_cat_id': '6'}},
#     'is_highlight_sub_cat': False,
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '141400',
#      'nickname': 'Winthepool',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1503977195,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1122864',
#     'cat_id': '1',
#     'sub_cat_id': '0',
#     'title': '[Gay]一人一個你最順眼同最睇唔順眼嘅gay佬紅人（97） 一',
#     'user_id': '221265',
#     'user_nickname': '原由柏実',
#     'user_gender': 'M',
#     'no_of_reply': '362',
#     'no_of_uni_user_reply': '27',
#     'like_count': '0',
#     'dislike_count': '0',
#     'reply_like_count': '12',
#     'reply_dislike_count': '15',
#     'max_reply_like_count': '3',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556090406,
#     'last_reply_time': 1556137446,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 2},
#     'last_reply_user_id': '96121',
#     'max_reply': '1001',
#     'total_page': 15,
#     'is_hot': False,
#     'category': {'cat_id': '1', 'name': '吹水台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '221265',
#      'nickname': '原由柏実',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1541718175,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123956',
#     'cat_id': '1',
#     'sub_cat_id': '0',
#     'title': '（曱甴實驗）曱甴都開始進化，愈嚟愈聰明。',
#     'user_id': '213889',
#     'user_nickname': '華特迪士尼',
#     'user_gender': 'F',
#     'no_of_reply': '14',
#     'no_of_uni_user_reply': '9',
#     'like_count': '14',
#     'dislike_count': '3',
#     'reply_like_count': '17',
#     'reply_dislike_count': '2',
#     'max_reply_like_count': '13',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556131139,
#     'last_reply_time': 1556137267,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '213889',
#     'max_reply': '1001',
#     'total_page': 1,
#     'is_hot': False,
#     'category': {'cat_id': '1', 'name': '吹水台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '213889',
#      'nickname': '華特迪士尼',
#      'level': '10',
#      'gender': 'F',
#      'status': '1',
#      'create_time': 1538399902,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1122755',
#     'cat_id': '17',
#     'sub_cat_id': '0',
#     'title': '一人一個不值一遊歐洲國家',
#     'user_id': '228934',
#     'user_nickname': '等寂寞到日出',
#     'user_gender': 'F',
#     'no_of_reply': '164',
#     'no_of_uni_user_reply': '129',
#     'like_count': '35',
#     'dislike_count': '316',
#     'reply_like_count': '1499',
#     'reply_dislike_count': '945',
#     'max_reply_like_count': '268',
#     'max_reply_dislike_count': '2',
#     'create_time': 1556086159,
#     'last_reply_time': 1556137267,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '232065',
#     'max_reply': '1001',
#     'total_page': 7,
#     'is_hot': True,
#     'category': {'cat_id': '17', 'name': '旅遊台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '228934',
#      'nickname': '等寂寞到日出',
#      'level': '10',
#      'gender': 'F',
#      'status': '1',
#      'create_time': 1546072196,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123401',
#     'cat_id': '11',
#     'sub_cat_id': '0',
#     'title': '覺唔覺marval個世界其實好on9?',
#     'user_id': '25345',
#     'user_nickname': '希特拉',
#     'user_gender': 'M',
#     'no_of_reply': '63',
#     'no_of_uni_user_reply': '45',
#     'like_count': '319',
#     'dislike_count': '129',
#     'reply_like_count': '716',
#     'reply_dislike_count': '295',
#     'max_reply_like_count': '156',
#     'max_reply_dislike_count': '9',
#     'create_time': 1556108371,
#     'last_reply_time': 1556137250,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '139671',
#     'max_reply': '1001',
#     'total_page': 3,
#     'is_hot': True,
#     'category': {'cat_id': '11', 'name': '影視台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '25345',
#      'nickname': '希特拉',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1480164246,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123983',
#     'cat_id': '11',
#     'sub_cat_id': '0',
#     'title': '係咪得我一個覺得今集AVG4個劇情好平平無奇?',
#     'user_id': '236379',
#     'user_nickname': '抽姐',
#     'user_gender': 'F',
#     'no_of_reply': '9',
#     'no_of_uni_user_reply': '8',
#     'like_count': '6',
#     'dislike_count': '5',
#     'reply_like_count': '8',
#     'reply_dislike_count': '2',
#     'max_reply_like_count': '2',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556134110,
#     'last_reply_time': 1556137246,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '163758',
#     'max_reply': '1001',
#     'total_page': 1,
#     'is_hot': False,
#     'category': {'cat_id': '11', 'name': '影視台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '236379',
#      'nickname': '抽姐',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1549970791,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123884',
#     'cat_id': '1',
#     'sub_cat_id': '0',
#     'title': '有人搭凌晨12點50分左右油塘站跌野 唔該入一入黎',
#     'user_id': '148252',
#     'user_nickname': '咪撚痴線啦',
#     'user_gender': 'M',
#     'no_of_reply': '8',
#     'no_of_uni_user_reply': '2',
#     'like_count': '2',
#     'dislike_count': '0',
#     'reply_like_count': '0',
#     'reply_dislike_count': '0',
#     'max_reply_like_count': '0',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556126518,
#     'last_reply_time': 1556137216,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '189453',
#     'max_reply': '1001',
#     'total_page': 1,
#     'is_hot': False,
#     'category': {'cat_id': '1', 'name': '吹水台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '148252',
#      'nickname': '咪撚痴線啦',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1505750526,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123962',
#     'cat_id': '1',
#     'sub_cat_id': '0',
#     'title': '外國撚入一入',
#     'user_id': '249229',
#     'user_nickname': '屎汁撈麵',
#     'user_gender': 'F',
#     'no_of_reply': '23',
#     'no_of_uni_user_reply': '8',
#     'like_count': '8',
#     'dislike_count': '1',
#     'reply_like_count': '32',
#     'reply_dislike_count': '1',
#     'max_reply_like_count': '6',
#     'max_reply_dislike_count': '1',
#     'create_time': 1556131965,
#     'last_reply_time': 1556137210,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 3},
#     'last_reply_user_id': '249229',
#     'max_reply': '1001',
#     'total_page': 1,
#     'is_hot': False,
#     'category': {'cat_id': '1', 'name': '吹水台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '249229',
#      'nickname': '屎汁撈麵',
#      'level': '10',
#      'gender': 'F',
#      'status': '1',
#      'create_time': 1555592778,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123545',
#     'cat_id': '33',
#     'sub_cat_id': '0',
#     'title': '其實大灣駒政治生涯已完(4)',
#     'user_id': '193138',
#     'user_nickname': '李潔瑩(淫kit)',
#     'user_gender': 'F',
#     'no_of_reply': '230',
#     'no_of_uni_user_reply': '47',
#     'like_count': '11',
#     'dislike_count': '8',
#     'reply_like_count': '299',
#     'reply_dislike_count': '87',
#     'max_reply_like_count': '14',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556113927,
#     'last_reply_time': 1556137204,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 2},
#     'last_reply_user_id': '26770',
#     'max_reply': '1001',
#     'total_page': 10,
#     'is_hot': False,
#     'category': {'cat_id': '33', 'name': '政事台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '193138',
#      'nickname': '李潔瑩(淫kit)',
#      'level': '10',
#      'gender': 'F',
#      'status': '1',
#      'create_time': 1530540830,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123506',
#     'cat_id': '16',
#     'sub_cat_id': '0',
#     'title': '( 極限食評 ) 瑪嘉烈醫院病人餐',
#     'user_id': '45206',
#     'user_nickname': '曹雪芹天下無雙',
#     'user_gender': 'F',
#     'no_of_reply': '154',
#     'no_of_uni_user_reply': '106',
#     'like_count': '1081',
#     'dislike_count': '14',
#     'reply_like_count': '3006',
#     'reply_dislike_count': '122',
#     'max_reply_like_count': '1031',
#     'max_reply_dislike_count': '5',
#     'create_time': 1556112245,
#     'last_reply_time': 1556137200,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '193091',
#     'max_reply': '1001',
#     'total_page': 7,
#     'is_hot': True,
#     'category': {'cat_id': '16', 'name': '飲食台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '45206',
#      'nickname': '曹雪芹天下無雙',
#      'level': '10',
#      'gender': 'F',
#      'status': '1',
#      'create_time': 1480483980,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123206',
#     'cat_id': '24',
#     'sub_cat_id': '0',
#     'title': 'Hottoys 1/6 1/4 Figures 討論區 154 We are in the ENDGAME now',
#     'user_id': '181504',
#     'user_nickname': 'R.D.J(壞左既人)',
#     'user_gender': 'M',
#     'no_of_reply': '284',
#     'no_of_uni_user_reply': '82',
#     'like_count': '2',
#     'dislike_count': '2',
#     'reply_like_count': '47',
#     'reply_dislike_count': '97',
#     'max_reply_like_count': '7',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556101813,
#     'last_reply_time': 1556137195,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '120712',
#     'max_reply': '1001',
#     'total_page': 12,
#     'is_hot': False,
#     'category': {'cat_id': '24', 'name': '玩具台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '181504',
#      'nickname': 'R.D.J(壞左既人)',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1523367997,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1032462',
#     'cat_id': '15',
#     'sub_cat_id': '0',
#     'title': '捕捉美國強勢股／Momentum Style - 5',
#     'user_id': '33263',
#     'user_nickname': '硬膠胸奴',
#     'user_gender': 'M',
#     'no_of_reply': '879',
#     'no_of_uni_user_reply': '69',
#     'like_count': '15',
#     'dislike_count': '1',
#     'reply_like_count': '159',
#     'reply_dislike_count': '81',
#     'max_reply_like_count': '4',
#     'max_reply_dislike_count': '0',
#     'create_time': 1550834489,
#     'last_reply_time': 1556137182,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '20076',
#     'max_reply': '1001',
#     'total_page': 36,
#     'is_hot': False,
#     'category': {'cat_id': '15', 'name': '財經台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '33263',
#      'nickname': '硬膠胸奴',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1480330594,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123204',
#     'cat_id': '5',
#     'sub_cat_id': '0',
#     'title': '古天樂談《權力的遊戲》最終季：相信我們也能做出這樣水準的電視劇',
#     'user_id': '39464',
#     'user_nickname': 'Puntis',
#     'user_gender': 'M',
#     'no_of_reply': '186',
#     'no_of_uni_user_reply': '160',
#     'like_count': '911',
#     'dislike_count': '25',
#     'reply_like_count': '2819',
#     'reply_dislike_count': '367',
#     'max_reply_like_count': '832',
#     'max_reply_dislike_count': '5',
#     'create_time': 1556101752,
#     'last_reply_time': 1556137153,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '120709',
#     'max_reply': '1001',
#     'total_page': 8,
#     'is_hot': False,
#     'category': {'cat_id': '5', 'name': '時事台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '39464',
#      'nickname': 'Puntis',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1480405342,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1121222',
#     'cat_id': '18',
#     'sub_cat_id': '6',
#     'title': '【唔包準】有興趣嘅入黎算命當聽個笑話',
#     'user_id': '51819',
#     'user_nickname': '伍貳貳',
#     'user_gender': 'M',
#     'no_of_reply': '91',
#     'no_of_uni_user_reply': '49',
#     'like_count': '3',
#     'dislike_count': '18',
#     'reply_like_count': '8',
#     'reply_dislike_count': '3',
#     'max_reply_like_count': '5',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556004938,
#     'last_reply_time': 1556137131,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 2},
#     'last_reply_user_id': '207505',
#     'max_reply': '1001',
#     'total_page': 4,
#     'is_hot': False,
#     'category': {'cat_id': '18', 'name': '學術台', 'postable': True},
#     'sub_category': {'sub_cat_id': '6',
#      'cat_id': '18',
#      'name': '神秘',
#      'postable': True,
#      'filterable': True,
#      'is_highlight': False,
#      'orderable': True,
#      'is_filter': False,
#      'url': 'https://lihkg.com/api_v2/thread/category',
#      'query': {'cat_id': '18', 'sub_cat_id': '6'}},
#     'is_highlight_sub_cat': False,
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '51819',
#      'nickname': '伍貳貳',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1480684182,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1098736',
#     'cat_id': '12',
#     'sub_cat_id': '0',
#     'title': '是咁的，照顧過我嘅護士死咗 完',
#     'user_id': '9848',
#     'user_nickname': '做金庸的男人',
#     'user_gender': 'M',
#     'no_of_reply': '585',
#     'no_of_uni_user_reply': '106',
#     'like_count': '279',
#     'dislike_count': '16',
#     'reply_like_count': '1981',
#     'reply_dislike_count': '219',
#     'max_reply_like_count': '39',
#     'max_reply_dislike_count': '1',
#     'create_time': 1554801918,
#     'last_reply_time': 1556137130,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '31847',
#     'max_reply': '1001',
#     'total_page': 24,
#     'is_hot': False,
#     'category': {'cat_id': '12', 'name': '講故台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '9848',
#      'nickname': '做金庸的男人',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1480089808,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1107788',
#     'cat_id': '31',
#     'sub_cat_id': '9',
#     'title': '我今次用LEGO砌左部.......☆跳樓機☆出黎，遊樂場果d機動遊戲呀',
#     'user_id': '67869',
#     'user_nickname': '閂埋門玩正氣',
#     'user_gender': 'M',
#     'no_of_reply': '70',
#     'no_of_uni_user_reply': '52',
#     'like_count': '804',
#     'dislike_count': '8',
#     'reply_like_count': '243',
#     'reply_dislike_count': '6',
#     'max_reply_like_count': '40',
#     'max_reply_dislike_count': '1',
#     'create_time': 1555334489,
#     'last_reply_time': 1556137124,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '111243',
#     'max_reply': '1001',
#     'total_page': 3,
#     'is_hot': True,
#     'category': {'cat_id': '31', 'name': '創意台', 'postable': True},
#     'sub_category': {'sub_cat_id': '9',
#      'cat_id': '31',
#      'name': '藝術設計',
#      'postable': True,
#      'filterable': False,
#      'is_highlight': True,
#      'orderable': True,
#      'is_filter': False,
#      'url': 'https://lihkg.com/api_v2/thread/category',
#      'query': {'cat_id': '31', 'sub_cat_id': '9'}},
#     'is_highlight_sub_cat': True,
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '67869',
#      'nickname': '閂埋門玩正氣',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1482154259,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}},
#    {'thread_id': '1123831',
#     'cat_id': '16',
#     'sub_cat_id': '0',
#     'title': '如果M記餐可以薯條換2塊薯餅，你肯加幾錢',
#     'user_id': '187905',
#     'user_nickname': '好啱呀',
#     'user_gender': 'M',
#     'no_of_reply': '26',
#     'no_of_uni_user_reply': '12',
#     'like_count': '46',
#     'dislike_count': '5',
#     'reply_like_count': '10',
#     'reply_dislike_count': '4',
#     'max_reply_like_count': '2',
#     'max_reply_dislike_count': '0',
#     'create_time': 1556124289,
#     'last_reply_time': 1556137097,
#     'status': '1',
#     'is_adu': False,
#     'remark': {'last_reply_count': 1},
#     'last_reply_user_id': '205371',
#     'max_reply': '1001',
#     'total_page': 2,
#     'is_hot': False,
#     'category': {'cat_id': '16', 'name': '飲食台', 'postable': True},
#     'is_bookmarked': False,
#     'is_replied': False,
#     'user': {'user_id': '187905',
#      'nickname': '好啱呀',
#      'level': '10',
#      'gender': 'M',
#      'status': '1',
#      'create_time': 1526992009,
#      'level_name': '普通會員',
#      'is_following': False,
#      'is_blocked': False,
#      'is_disappear': False}}]}}

# %%
conn = lite.connect(':memory:')
cursor = conn.cursor()
cursor.execute('''CREATE TABLE LIHKG
(quote_post_id text, thread_id text, user_nickname text, post_id text, msg text)''')
conn.commit()
print('create table sussece')
# Out:
# create table sussece

# %%
#Save thread_id and total page
for scr in data['response']['items']:
    for i in range(scr['total_page']):
        dict = {scr['thread_id']:scr['total_page']}
        url.update(dict)
        #print(scr['title'], ': ', base + 'thread/' + scr['thread_id'] + '/page/' + str(i+1))
    time.sleep(0.1)

# %%
#test
res = requests.get(base + 'api_v2/thread/{}/page/{}?order=reply_time'.format(1117179, 1))
data = json.loads(res.text)
#print(data['response']['item_data'])
for datas in data['response']['item_data']:
    dict = {'thread_id':datas['thread_id'], datas['post_id']:{'user_name':datas['user_nickname'], 'msg':datas['msg']}}
    user.append(dict)
print(user)
#when a msg have qoute a post
#it should be have a quote_post_id
#so we just note the id_and_post to hash
# Out:
# [{'thread_id': '1117179',
#   'f713658e11201144208073a45445d045ca07e5c6': {'user_name': '周珉金彩元惠姜',
#    'msg': '<img src="/assets/faces/normal/cry.gif" class="hkgmoji" />首先一間屋6個人 黑櫻勢力都幾大<br />\n牙包 ( 日本妹 , 為左將來返AKB後路一定順和牙宮)<br />\n牙奈 ( 日本妹 , 大家都HKT ,同一條水 同聲同氣)<br />\n牙演 ( PD48已經同牙宮FD到仆街 一定撐牙宮) <br />\n柔理 ( 應該係最識做人 附和下阿宮 又安慰下牙英)<br />\n諗到牙英(14碎)係一間屋入面 比黑櫻恰 已經想像到四條友恰鳩牙英妹 <br />\n真係好慘<img src="/assets/faces/normal/frown.gif" class="hkgmoji" />'}},
#  {'thread_id': '1117179',
#   'fd1f830525315911a60f310759193a6f61aabcb9': {'user_name': '周珉金彩元惠姜',
#    'msg': '諗起佢4條友用日文細聲講 大聲笑黎搞鳩英妹 好心痛<img src="/assets/faces/dog/cry.gif" class="hkgmoji" />'}},
#  {'thread_id': '1117179',
#   'ffc67f4f1da292c6c2cbef31ea65a13b7c4ed153': {'user_name': '勝利（已失敗）',
#    'msg': '實唔想返 佢長期喺我到瞓'}},
#  {'thread_id': '1117179',
#   'ae0c4464d66e61ba1fd6a7db78b26198443b16ef': {'user_name': '周珉金彩元惠姜',
#    'msg': '躝啦 唔接受BLINK入黎討論'}},
#  {'thread_id': '1117179',
#   'da08e1bc26925b3429f0b6e1581455e37db964f1': {'user_name': '勝利（已失敗）',
#    'msg': '都話咗我reveluv嚟<img src="/assets/faces/normal/clown.gif" class="hkgmoji" />'}}]

# %%
#Save information of those page
#https://lihkg.com/api_v2/thread/1117179/page/1?order=reply_time
for urls in url:
    for i in range(url[urls]):
        res = requests.get(base + 'api_v2/thread/{}/page/{}?order=reply_time'.format(urls, i+1))
        data = json.loads(res.text)
        for datas in data['response']['item_data']:
            print(datas)
            dict = {'thread_id':datas['thread_id'], datas['post_id']:{'user_name':datas['user_nickname'], 'msg':datas['msg']}}
            user.append(dict)

# %%
user
